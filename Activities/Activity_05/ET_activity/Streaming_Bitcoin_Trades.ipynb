# %% [markdown]
# # Streaming Data Acquisition - From Raw Stream to Clean CSV

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 1: Setup and Architecture

# %% [markdown]
# ### Install the necessary libraries:
# 1. **websocket-client**: To establish the persistent connection.
# 2. **pandas**: To process, clean, and export the collected data.

# %%
# !pip install websocket-client pandas
print("Dependencies installed successfully.")
# Out:
# Requirement already satisfied: websocket-client in /home/codespace/.local/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Dependencies installed successfully.

# %%
## Import all required Python modules

# %%
import websocket
import json
import time
import threading
import pandas as pd
from datetime import datetime

print("Modules imported.")
# Out:
# Modules imported.

# %% [markdown]
# ### Define Global Configuration and Storage
# This cell sets the target URL and initializes the empty list that will collect all the raw messages pushed from the server.

# %%
# --- Configuration ---
# Target URL for the Binance BTC/USDT trade stream (using the stable fstream endpoint)
STREAM_URL = "wss://fstream.binance.com/ws/btcusdt@trade" 

# --- Global Storage ---
# This list will collect every single message (event) pushed by the server.
raw_data_collector = []

print(f"Target Stream URL set: {STREAM_URL}")
print("Raw data collector initialized.")
# Out:
# Target Stream URL set: wss://fstream.binance.com/ws/btcusdt@trade
# Raw data collector initialized.

# %% [markdown]
# ### Define the `on_open` Callback
# This function runs only once when the persistent connection is successfully established.

# %%
def on_open(ws):
    """Callback: Executed when the connection handshake is successful."""
    print("--- Connection Established. Starting Real-Time Data Stream ---")
    
print("on_open callback defined.")
# Out:
# on_open callback defined.

# %% [markdown]
# ### Define the `on_error` and `on_close` Callbacks
# These functions handle connection failures and the graceful shutdown of the stream.

# %%
def on_error(ws, error):
    """Callback: Executed if an error occurs during the connection."""
    print(f"--- Connection Error: {error} ---")

def on_close(ws, close_status_code, close_msg):
    """Callback: Executed when the connection is intentionally closed."""
    print("--- Connection Closed ---")
    
print("on_error and on_close callbacks defined.")
# Out:
# on_error and on_close callbacks defined.

# %% [markdown]
# ### Define the `on_message` Callback (Raw Capture Logic)
# This is the most critical function. It runs for every incoming message. For the first run, we will not filter anything.

# %%
def on_message(ws, message):
    """Callback: Executed for EVERY message pushed by the server."""
    global raw_data_collector
    
    try:
        data = json.loads(message)
        
        # 1. Store the RAW, unfiltered message dictionary
        raw_data_collector.append(data)
        
        # 2. Extract and format key fields for immediate screen output
        trade_time = datetime.fromtimestamp(data['E'] / 1000).strftime('%H:%M:%S')
        price = float(data.get('p', 0))
        volume = float(data.get('q', 0))
        
        # Print everything that comes in, including potential 0-value keep-alives
        print(f"[{trade_time}] RAW Trade: Price=${price:,.2f} | Volume={volume}")

    except Exception as e:
        # Ignore errors from malformed JSON (rare, but possible)
        pass 
    
print("on_message callback defined for RAW data capture.")
# Out:
# on_message callback defined for RAW data capture.

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 2: RAW Stream Capture and Observation

# %% [markdown]
# ### Create the WebSocket Client Object

# %%
# Clear the collector list before starting a new run
raw_data_collector = []

# Create the WebSocketApp instance, linking the URL to the callback functions
ws = websocket.WebSocketApp(
    STREAM_URL,
    on_message=on_message,
    on_open=on_open,
    on_error=on_error,
    on_close=on_close
)

print("WebSocket client object created, ready to connect.")
# Out:
# WebSocket client object created, ready to connect.

# %% [markdown]
# ### Start, Run, and Close the Stream Listener
# This cell starts the connection in a separate thread and uses time.sleep() to control the duration.

# %%
print("Starting RAW stream listener for 15 seconds. OBSERVE THE OUTPUT CAREFULLY.")

# Run the socket connection in a separate thread
wst = threading.Thread(target=ws.run_forever)
wst.daemon = True
wst.start()

# Hold the main thread execution for 15 seconds
time.sleep(15) 

print("Time's up. Attempting to close connection...")

# Close the connection gracefully.
ws.close() 

print(f"\nFinished RAW capture. Collected {len(raw_data_collector)} total raw messages.")
# Out:
# Starting RAW stream listener for 15 seconds. OBSERVE THE OUTPUT CAREFULLY.
# --- Connection Established. Starting Real-Time Data Stream ---
# [00:00:37] RAW Trade: Price=$114,192.10 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.10 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.10 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.10 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.148
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.004
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.004
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.006
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.007
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.005
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.004
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.003
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.006
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.023
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.076
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.048
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.006
# [00:00:37] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:37] RAW Trade: Price=$114,192.00 | Volume=0.002
# [00:00:38] RAW Trade: Price=$114,192.00 | Volume=0.206
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.05
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.088
# [00:00:38] RAW Trade: Price=$114,192.00 | Volume=0.916
# [00:00:38] RAW Trade: Price=$114,192.00 | Volume=0.429
# [00:00:38] RAW Trade: Price=$114,192.00 | Volume=0.021
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.087
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.004
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.71
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.015
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.259
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.002
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.053
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.259
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.004
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.052
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.052
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.052
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.002
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.002
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.025
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.155
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.125
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.207
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.053
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=1.191
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.25
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.172
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.177
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.002
# [00:00:38] RAW Trade: Price=$114,191.90 | Volume=0.566
# [00:00:38] RAW Trade: Price=$114,192.00 | Volume=0.006
# [00:00:39] RAW Trade: Price=$114,191.90 | Volume=0.044
# [00:00:39] RAW Trade: Price=$114,191.90 | Volume=0.069
# [00:00:39] RAW Trade: Price=$114,192.00 | Volume=0.015
# [00:00:39] RAW Trade: Price=$114,192.00 | Volume=0.184
# [00:00:39] RAW Trade: Price=$114,192.00 | Volume=0.002
# [00:00:39] RAW Trade: Price=$114,191.90 | Volume=0.088
# [00:00:39] RAW Trade: Price=$114,192.00 | Volume=0.008
# [00:00:39] RAW Trade: Price=$114,192.00 | Volume=0.1
# [00:00:39] RAW Trade: Price=$114,192.00 | Volume=0.008
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.088
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.014
# [00:00:40] RAW Trade: Price=$114,192.00 | Volume=0.008
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.021
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.25
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.052
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.052
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.052
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.011
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.052
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.017
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.006
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.007
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,191.80 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,191.80 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,191.80 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,191.80 | Volume=0.015
# [00:00:40] RAW Trade: Price=$114,191.80 | Volume=0.004
# [00:00:40] RAW Trade: Price=$114,191.50 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,191.30 | Volume=0.038
# [00:00:40] RAW Trade: Price=$114,191.20 | Volume=0.05
# [00:00:40] RAW Trade: Price=$114,191.20 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,190.90 | Volume=0.034
# [00:00:40] RAW Trade: Price=$114,190.60 | Volume=0.028
# [00:00:40] RAW Trade: Price=$114,190.40 | Volume=0.05
# [00:00:40] RAW Trade: Price=$114,190.40 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,190.40 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,190.00 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,189.80 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,189.70 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,189.30 | Volume=0.004
# [00:00:40] RAW Trade: Price=$114,189.20 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,189.10 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,189.10 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,188.80 | Volume=0.065
# [00:00:40] RAW Trade: Price=$114,188.40 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,188.20 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,188.10 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,188.10 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,188.10 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,188.00 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,187.50 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.026
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.011
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.03
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.004
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.002
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.004
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.006
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.004
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.005
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.005
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.004
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.001
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.117
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.03
# [00:00:40] RAW Trade: Price=$114,187.40 | Volume=0.087
# [00:00:40] RAW Trade: Price=$114,187.50 | Volume=0.062
# [00:00:40] RAW Trade: Price=$114,187.50 | Volume=0.008
# [00:00:40] RAW Trade: Price=$114,187.50 | Volume=0.115
# [00:00:41] RAW Trade: Price=$114,187.40 | Volume=0.087
# [00:00:41] RAW Trade: Price=$114,187.40 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,187.40 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.008
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.742
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.088
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.089
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.5
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.117
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.008
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.034
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.087
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.008
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.003
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.003
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.009
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.003
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,187.50 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,187.60 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,187.60 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,188.00 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,188.10 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,188.40 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,189.00 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,189.10 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,189.70 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,190.00 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,190.00 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,190.40 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,190.60 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,191.00 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,191.30 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,191.40 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,191.60 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,192.00 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,192.00 | Volume=0.007
# [00:00:41] RAW Trade: Price=$114,192.00 | Volume=0.008
# [00:00:41] RAW Trade: Price=$114,192.00 | Volume=0.008
# [00:00:41] RAW Trade: Price=$114,192.00 | Volume=0.087
# [00:00:41] RAW Trade: Price=$114,192.00 | Volume=0.048
# [00:00:41] RAW Trade: Price=$114,192.00 | Volume=0.165
# [00:00:41] RAW Trade: Price=$114,192.00 | Volume=0.054
# [00:00:41] RAW Trade: Price=$114,192.00 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,192.00 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,192.10 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,192.20 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,192.40 | Volume=0.01
# [00:00:41] RAW Trade: Price=$114,192.50 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,192.80 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,193.20 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,193.30 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,193.40 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,193.50 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,193.70 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,193.80 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,193.80 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,194.40 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,194.40 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,194.70 | Volume=0.003
# [00:00:41] RAW Trade: Price=$114,194.80 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,195.00 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,195.00 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,195.10 | Volume=0.002
# [00:00:41] RAW Trade: Price=$114,195.20 | Volume=0.001
# [00:00:41] RAW Trade: Price=$114,195.30 | Volume=0.207
# [00:00:41] RAW Trade: Price=$114,195.30 | Volume=0.003
# [00:00:41] RAW Trade: Price=$114,195.30 | Volume=0.008
# [00:00:41] RAW Trade: Price=$0.00 | Volume=0.0
# [00:00:41] RAW Trade: Price=$114,195.30 | Volume=0.002
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.027
# [00:00:42] RAW Trade: Price=$114,195.30 | Volume=0.024
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.088
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.125
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.276
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.209
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.5
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.287
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.436
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.846
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.052
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.012
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.05
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.002
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.014
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.002
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.015
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.003
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.006
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,195.20 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,195.10 | Volume=0.002
# [00:00:42] RAW Trade: Price=$114,195.10 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,195.10 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,195.10 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,195.00 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,194.40 | Volume=0.05
# [00:00:42] RAW Trade: Price=$114,194.30 | Volume=0.002
# [00:00:42] RAW Trade: Price=$114,193.80 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,193.40 | Volume=0.003
# [00:00:42] RAW Trade: Price=$114,193.40 | Volume=0.032
# [00:00:42] RAW Trade: Price=$114,192.90 | Volume=0.001
# [00:00:42] RAW Trade: Price=$114,192.50 | Volume=0.002
# [00:00:42] RAW Trade: Price=$114,192.00 | Volume=0.008
# [00:00:42] RAW Trade: Price=$114,191.90 | Volume=0.004
# [00:00:42] RAW Trade: Price=$114,191.90 | Volume=0.718
# [00:00:42] RAW Trade: Price=$114,191.90 | Volume=0.522
# [00:00:42] RAW Trade: Price=$114,191.90 | Volume=0.059
# [00:00:42] RAW Trade: Price=$114,191.90 | Volume=0.088
# [00:00:42] RAW Trade: Price=$114,191.90 | Volume=0.027
# [00:00:42] RAW Trade: Price=$114,191.90 | Volume=0.042
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.27
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=1.022
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.85
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.218
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.574
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=2.452
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.377
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=1.126
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.671
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.061
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.328
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=2.111
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=2.552
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.261
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.208
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=5.164
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.539
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=1.643
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.80 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.60 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,191.50 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,190.90 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,190.30 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,190.20 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,190.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,189.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,189.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,189.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,189.30 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,189.20 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,189.10 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,188.70 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,188.40 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,188.20 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,188.10 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,188.00 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,187.80 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,187.50 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,187.40 | Volume=0.011
# [00:00:43] RAW Trade: Price=$114,187.40 | Volume=0.066
# [00:00:43] RAW Trade: Price=$114,187.40 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,187.40 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,187.40 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,187.30 | Volume=0.034
# [00:00:43] RAW Trade: Price=$114,187.30 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,186.90 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,186.90 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,186.90 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,186.90 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,186.60 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,186.50 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,186.50 | Volume=0.054
# [00:00:43] RAW Trade: Price=$114,186.40 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,186.40 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,186.40 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,186.40 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,186.30 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,186.20 | Volume=0.04
# [00:00:43] RAW Trade: Price=$114,186.20 | Volume=0.02
# [00:00:43] RAW Trade: Price=$114,186.20 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,185.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,185.80 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,185.30 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,185.30 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,185.10 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,185.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,184.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,184.60 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,184.60 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,184.60 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,184.00 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,183.90 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,183.50 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,183.50 | Volume=0.04
# [00:00:43] RAW Trade: Price=$114,183.40 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,183.40 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,183.30 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,183.30 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,183.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,182.70 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,182.40 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,182.10 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,185.40 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.70 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.70 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.60 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.30 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,181.20 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,181.00 | Volume=0.008
# [00:00:43] RAW Trade: Price=$114,181.00 | Volume=0.723
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.049
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.051
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.056
# [00:00:43] RAW Trade: Price=$114,180.90 | Volume=0.05
# [00:00:43] RAW Trade: Price=$114,180.10 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.012
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.075
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.001
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.014
# [00:00:43] RAW Trade: Price=$114,180.00 | Volume=0.002
# [00:00:43] RAW Trade: Price=$114,180.10 | Volume=0.01
# [00:00:43] RAW Trade: Price=$114,180.10 | Volume=0.011
# [00:00:43] RAW Trade: Price=$114,180.10 | Volume=0.005
# [00:00:43] RAW Trade: Price=$114,180.10 | Volume=0.011
# [00:00:43] RAW Trade: Price=$114,180.10 | Volume=0.003
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.135
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.149
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.103
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.149
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.026
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.103
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.138
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.019
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.008
# [00:00:44] RAW Trade: Price=$114,180.00 | Volume=0.088
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.037
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.026
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.064
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.064
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.088
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.088
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.118
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.118
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.064
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.125
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.064
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.023
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.011
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.268
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.007
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.036
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.017
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.349
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.005
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.011
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.028
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.355
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.188
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.006
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,180.10 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,180.20 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,180.20 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,180.20 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,180.60 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,181.00 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,181.00 | Volume=0.018
# [00:00:44] RAW Trade: Price=$114,181.00 | Volume=0.24
# [00:00:44] RAW Trade: Price=$114,181.00 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,181.00 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,181.00 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,181.00 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,181.00 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,181.00 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,181.00 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,181.00 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,181.10 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,181.20 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,181.90 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,181.90 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,181.90 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,181.90 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,183.00 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,183.00 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,183.30 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,183.30 | Volume=0.087
# [00:00:44] RAW Trade: Price=$114,183.80 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,184.00 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,184.90 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,184.90 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,185.00 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,185.50 | Volume=0.065
# [00:00:44] RAW Trade: Price=$114,185.70 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,186.10 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,186.40 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,187.00 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,187.00 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,187.60 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,188.20 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,188.20 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,188.40 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,188.80 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,188.80 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,189.60 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,189.90 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,190.00 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,190.00 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,190.30 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,191.00 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,191.00 | Volume=0.205
# [00:00:44] RAW Trade: Price=$114,191.00 | Volume=0.009
# [00:00:44] RAW Trade: Price=$114,191.00 | Volume=0.059
# [00:00:44] RAW Trade: Price=$114,191.00 | Volume=0.087
# [00:00:44] RAW Trade: Price=$114,191.00 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,191.00 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,191.00 | Volume=0.35
# [00:00:44] RAW Trade: Price=$114,191.00 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,191.10 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,191.10 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,191.10 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,191.30 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,191.60 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,191.60 | Volume=0.003
# [00:00:44] RAW Trade: Price=$114,192.00 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,192.00 | Volume=0.05
# [00:00:44] RAW Trade: Price=$114,192.10 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,192.40 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,192.60 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,192.60 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,192.80 | Volume=0.05
# [00:00:44] RAW Trade: Price=$114,193.20 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,193.20 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,193.30 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,193.50 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,193.80 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,193.80 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,194.30 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,194.50 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,194.80 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,194.80 | Volume=0.007
# [00:00:44] RAW Trade: Price=$114,195.00 | Volume=0.002
# [00:00:44] RAW Trade: Price=$114,195.00 | Volume=0.001
# [00:00:44] RAW Trade: Price=$114,195.20 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,195.20 | Volume=0.02
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=0.008
# [00:00:45] RAW Trade: Price=$114,195.20 | Volume=0.006
# [00:00:45] RAW Trade: Price=$114,195.20 | Volume=0.088
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=0.031
# [00:00:45] RAW Trade: Price=$114,195.20 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=0.008
# [00:00:45] RAW Trade: Price=$114,195.20 | Volume=0.007
# [00:00:45] RAW Trade: Price=$114,195.20 | Volume=0.129
# [00:00:45] RAW Trade: Price=$114,195.20 | Volume=0.004
# [00:00:45] RAW Trade: Price=$114,195.20 | Volume=0.004
# [00:00:45] RAW Trade: Price=$114,195.20 | Volume=0.012
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=1.708
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=0.009
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=0.008
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=0.009
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,195.30 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,195.40 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,195.40 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,195.40 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,195.50 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,196.00 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,196.00 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.00 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,196.10 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,196.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.40 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,196.50 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,196.70 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,197.10 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,197.10 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,197.30 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,197.30 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,197.30 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,197.40 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,197.70 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,197.90 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,198.20 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,198.30 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,198.40 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,198.50 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,198.80 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,199.10 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,199.20 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,199.30 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,199.40 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,199.40 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,199.60 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,199.70 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,199.80 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,200.00 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,200.00 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,200.40 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,200.50 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,200.60 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,201.00 | Volume=0.06
# [00:00:45] RAW Trade: Price=$114,201.10 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,201.20 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,201.50 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,201.50 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,201.50 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,201.70 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,201.70 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,201.80 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,202.40 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,202.50 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,202.60 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,203.10 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,203.20 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,203.30 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,203.70 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,204.10 | Volume=0.003
# [00:00:45] RAW Trade: Price=$114,204.30 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,204.40 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,204.60 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,204.70 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,204.80 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,204.90 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,205.00 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,205.00 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,205.10 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,205.20 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,205.20 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,205.40 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,205.40 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,205.40 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,205.50 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,205.70 | Volume=0.006
# [00:00:45] RAW Trade: Price=$114,206.10 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,206.10 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,206.40 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,206.40 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,206.40 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,206.50 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,206.70 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,207.10 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,207.20 | Volume=0.003
# [00:00:45] RAW Trade: Price=$114,207.30 | Volume=0.002
# [00:00:45] RAW Trade: Price=$114,207.40 | Volume=0.003
# [00:00:45] RAW Trade: Price=$114,207.40 | Volume=0.044
# [00:00:45] RAW Trade: Price=$114,207.40 | Volume=0.001
# [00:00:45] RAW Trade: Price=$114,207.40 | Volume=0.176
# [00:00:45] RAW Trade: Price=$114,207.40 | Volume=0.18
# [00:00:45] RAW Trade: Price=$114,207.40 | Volume=0.047
# [00:00:45] RAW Trade: Price=$114,207.40 | Volume=0.006
# [00:00:46] RAW Trade: Price=$114,207.30 | Volume=0.02
# [00:00:46] RAW Trade: Price=$114,207.40 | Volume=0.004
# [00:00:46] RAW Trade: Price=$114,207.30 | Volume=0.044
# [00:00:46] RAW Trade: Price=$114,207.30 | Volume=0.044
# [00:00:46] RAW Trade: Price=$114,207.40 | Volume=0.008
# [00:00:46] RAW Trade: Price=$114,207.40 | Volume=0.006
# [00:00:46] RAW Trade: Price=$114,207.40 | Volume=0.002
# [00:00:47] RAW Trade: Price=$114,207.30 | Volume=0.088
# [00:00:47] RAW Trade: Price=$114,207.30 | Volume=0.003
# [00:00:47] RAW Trade: Price=$114,207.40 | Volume=0.008
# [00:00:47] RAW Trade: Price=$0.00 | Volume=0.0
# [00:00:47] RAW Trade: Price=$114,207.40 | Volume=0.005
# [00:00:47] RAW Trade: Price=$114,207.40 | Volume=0.008
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.01
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.009
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.009
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.137
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.262
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.004
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.021
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.018
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.172
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.008
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.006
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,207.30 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,207.20 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,207.20 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,207.20 | Volume=0.004
# [00:00:48] RAW Trade: Price=$114,206.80 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,206.30 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,205.20 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,205.20 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,205.00 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,205.00 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,204.60 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,204.60 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,204.60 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,204.10 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,203.80 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,203.50 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,203.30 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,203.20 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,202.90 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,202.90 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,202.60 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,202.30 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,202.00 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,202.00 | Volume=0.065
# [00:00:48] RAW Trade: Price=$114,202.00 | Volume=0.004
# [00:00:48] RAW Trade: Price=$114,201.90 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,201.80 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,201.80 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,201.70 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,201.60 | Volume=0.06
# [00:00:48] RAW Trade: Price=$114,201.60 | Volume=0.009
# [00:00:48] RAW Trade: Price=$114,201.60 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,201.60 | Volume=0.018
# [00:00:48] RAW Trade: Price=$114,201.60 | Volume=0.01
# [00:00:48] RAW Trade: Price=$114,201.20 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,201.10 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,200.90 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,200.90 | Volume=0.015
# [00:00:48] RAW Trade: Price=$114,200.60 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,200.30 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,200.10 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,200.10 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,200.00 | Volume=0.001
# [00:00:48] RAW Trade: Price=$114,200.00 | Volume=0.087
# [00:00:48] RAW Trade: Price=$114,200.10 | Volume=0.002
# [00:00:48] RAW Trade: Price=$114,200.10 | Volume=0.009
# [00:00:48] RAW Trade: Price=$114,200.10 | Volume=0.008
# [00:00:48] RAW Trade: Price=$114,200.10 | Volume=0.031
# [00:00:49] RAW Trade: Price=$114,200.00 | Volume=0.088
# [00:00:49] RAW Trade: Price=$114,200.00 | Volume=0.002
# [00:00:50] RAW Trade: Price=$114,200.00 | Volume=0.088
# [00:00:50] RAW Trade: Price=$114,200.00 | Volume=0.028
# [00:00:50] RAW Trade: Price=$114,200.00 | Volume=0.097
# [00:00:50] RAW Trade: Price=$114,200.00 | Volume=0.003
# [00:00:50] RAW Trade: Price=$114,200.00 | Volume=0.062
# [00:00:51] RAW Trade: Price=$114,200.00 | Volume=0.088
# [00:00:51] RAW Trade: Price=$114,200.00 | Volume=0.007
# [00:00:51] RAW Trade: Price=$114,200.10 | Volume=0.001
# [00:00:51] RAW Trade: Price=$114,200.10 | Volume=0.001
# Time's up. Attempting to close connection...
# --- Connection Closed ---
#
# Finished RAW capture. Collected 763 total raw messages.

# %% [markdown]
# ### Commentary - Why the $0 Trades?
#
# --- Observation: The Data Quality Problem ---
#
# You should have observed several messages showing Price=$0.00 or Volume=0.
#
# These are **Keep-Alive (Ping/Pong) Messages**. They are network heartbeats, NOT valid trades.
#
# If we analyzed this raw data, the 0-values would skew our average price and volume calculations.
#
# Our next step is to apply a **Filter** to discard them.

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 3: Data Transformation and Export

# %% [markdown]
# ### Load Raw Data into Pandas
# This is the start of the Transformation (T) phase from ETL.

# %%
# Convert the list of dictionaries collected in Phase 2 into a Pandas DataFrame
df_raw = pd.DataFrame(raw_data_collector)

print(f"DataFrame loaded with {len(df_raw)} raw messages.")
print("Raw DataFrame columns:")
print(df_raw.columns.tolist())
display(df_raw.head())
# Out:
# DataFrame loaded with 763 raw messages.
# Raw DataFrame columns:
# ['e', 'E', 'T', 's', 't', 'p', 'q', 'X', 'm']
#        e              E              T        s           t          p      q  \
# 0  trade  1759190437503  1759190437503  BTCUSDT  6666777567  114192.10  0.001
# 1  trade  1759190437667  1759190437666  BTCUSDT  6666777568  114192.10  0.001
# 2  trade  1759190437854  1759190437854  BTCUSDT  6666777569  114192.10  0.001
# 3  trade  1759190437873  1759190437873  BTCUSDT  6666777570  114192.10  0.001
# 4  trade  1759190437887  1759190437886  BTCUSDT  6666777571  114192.00  0.001
#
#         X      m
# 0  MARKET  False
# 1  MARKET  False
# 2  MARKET  False
# 3  MARKET  False
# 4  MARKET   True

# %% [markdown]
# ### Data Preparation (Type Conversion)
# The price and volume columns were read as strings or objects. We must convert them to numeric types before filtering.

# %%
# Convert price ('p') and volume ('q') columns to numeric types.
df_raw['p'] = pd.to_numeric(df_raw['p'], errors='coerce')
df_raw['q'] = pd.to_numeric(df_raw['q'], errors='coerce')

print("Price ('p') and Volume ('q') columns converted to numeric (float).")
# Out:
# Price ('p') and Volume ('q') columns converted to numeric (float).

# %% [markdown]
# ### Apply the Cleaning Filter
# This cell applies the filter to eliminate the keep-alive messages.

# %%
print(f"Messages before filtering: {len(df_raw)}")

# --- APPLY THE DATA QUALITY FILTER ---
# A valid trade must have a positive price AND a positive volume.
df_clean = df_raw[(df_raw['p'] > 0) & (df_raw['q'] > 0)].copy()

print(f"Messages after filtering: {len(df_clean)}")
print(f"Successfully filtered out {len(df_raw) - len(df_clean)} keep-alive messages.")

display(df_clean.head())
# Out:
# Messages before filtering: 763
# Messages after filtering: 761
# Successfully filtered out 2 keep-alive messages.
#        e              E              T        s           t         p      q  \
# 0  trade  1759190437503  1759190437503  BTCUSDT  6666777567  114192.1  0.001
# 1  trade  1759190437667  1759190437666  BTCUSDT  6666777568  114192.1  0.001
# 2  trade  1759190437854  1759190437854  BTCUSDT  6666777569  114192.1  0.001
# 3  trade  1759190437873  1759190437873  BTCUSDT  6666777570  114192.1  0.001
# 4  trade  1759190437887  1759190437886  BTCUSDT  6666777571  114192.0  0.001
#
#         X      m
# 0  MARKET  False
# 1  MARKET  False
# 2  MARKET  False
# 3  MARKET  False
# 4  MARKET   True

# %% [markdown]
# ### Add Human-Readable Columns
# The raw data uses short keys like 'E' (Event Time) and 's' (Symbol). We create descriptive columns for the final CSV.

# %%
# Convert 'E' (milliseconds since epoch) to a readable timestamp
df_clean['Trade_Time'] = pd.to_datetime(df_clean['E'], unit='ms')

# Create descriptive columns
df_clean['Price_USD'] = df_clean['p']
df_clean['Volume_BTC'] = df_clean['q']

print("Human-readable columns (Trade_Time, Price_USD, Volume_BTC) created.")
# Out:
# Human-readable columns (Trade_Time, Price_USD, Volume_BTC) created.

# %% [markdown]
# ### Select Final Columns
# Select only the essential, clean, and formatted columns for the final file.

# %%
# Select and rename final columns for a clean output structure
df_final = df_clean[['Trade_Time', 'Price_USD', 'Volume_BTC', 's']].rename(
    columns={'s': 'Symbol'}
)

print("Final DataFrame structure prepared.")
display(df_final.head())
# Out:
# Final DataFrame structure prepared.
#                Trade_Time  Price_USD  Volume_BTC   Symbol
# 0 2025-09-30 00:00:37.503   114192.1       0.001  BTCUSDT
# 1 2025-09-30 00:00:37.667   114192.1       0.001  BTCUSDT
# 2 2025-09-30 00:00:37.854   114192.1       0.001  BTCUSDT
# 3 2025-09-30 00:00:37.873   114192.1       0.001  BTCUSDT
# 4 2025-09-30 00:00:37.887   114192.0       0.001  BTCUSDT

# %% [markdown]
# ### Export to CSV
# This is the Load (L) phase of ETL.

# %%
# Define the output filename
output_filename = 'btc_usdt_stream_clean.csv'

# Export the clean DataFrame to a CSV file without the pandas index
df_final.to_csv(output_filename, index=False)

print(f"--- Load Phase Complete ---")
print(f"Clean, filtered stream data successfully exported to: {output_filename}")
# Out:
# --- Load Phase Complete ---
# Clean, filtered stream data successfully exported to: btc_usdt_stream_clean.csv
